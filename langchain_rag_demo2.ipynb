# %%
from dotenv import load_dotenv
from langchain_core.documents import Document
from langchain_core.prompts import PromptTemplate

load_dotenv()

from langchain.chat_models import init_chat_model
import os

DeepSeek_API_KEY = os.getenv("DEEPSEEK_API_KEY")
chat_model = init_chat_model("deepseek-chat", model_provider="deepseek")

from langchain_community.embeddings import DashScopeEmbeddings

DashScope_API_KEY = os.getenv("DASHSCOPE_API_KEY")
embedding_model = DashScopeEmbeddings(
    model="text-embedding-v4",
    dashscope_api_key=DashScope_API_KEY
)

# from langchain_openai import OpenAIEmbeddings
#
# embedding_model = OpenAIEmbeddings()

# 读取数据源
src = "/mnt/c/Users/22695/Desktop/笔记/毕业论文/参考论文/中文/基于自适应图学习的深度多视图聚类算法研究_普敬誉.pdf"
from langchain_community.document_loaders import PyPDFLoader

# doc_loader = PyPDFLoader(file_path=src).load()

from PyPDF2 import PdfReader

docs = PdfReader(src)
content = []
for page in docs.pages:
    content.append(page.extract_text())

text = "".join(content)

from langchain_text_splitters import TextSplitter, RecursiveCharacterTextSplitter, MarkdownTextSplitter

splitter = RecursiveCharacterTextSplitter()
chunks = splitter.split_text(text)
docs = splitter.create_documents(chunks)

from langchain_community.vectorstores import FAISS
# vs = FAISS.from_texts(chunks, embedding=embedding_model)
# vs.save_local("faiss_db_v2")


vs = FAISS.load_local("faiss_db_v2", embeddings=embedding_model, allow_dangerous_deserialization=True)
query = "这篇文章有哪些贡献？"
top_k = 3
# top_k_chunks = vs.similarity_search(query, top_k=top_k)
retriever = vs.as_retriever(search_kwargs={"k": 3})

# retriever_document_chain = (
#     itemgetter("messages")
#     | RunnableLambda(extract_question)
#     | retriever
# )
results = retriever.invoke(query)

for doc in results:
    print(f"Content: {doc.page_content}")

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 定义提示词模板
prompt = PromptTemplate(
    input_variables = ["question"],
    template = "你是一个乐于助人的智能小助理，请根据用户输入的问题给出一个简短的回答：{question}"
)

# 构建chains
chain = prompt | chat_model | StrOutputParser()

response = chain.invoke({"question": "请问什么是人工智能？"})
print(response)

from langchain_core.runnables import RunnableLambda
from operator import itemgetter

# 问题是历史记录中的最后一项
def extract_question(input):
    return input[-1]["content"]

# 历史记录是除了最后一个问题之外的所有内容
def extract_history(input):
    return input[:-1]

prompt_with_history_str = \
"""
你是一个论文阅读助手，请只根据检索到的论文内容片段回答相关问题。
如果你不知道如何回答或者这个问题与检索到内容片段无关，就提示无法回答，并给出无法回答的原因。
这是你与用户对话的历史记录：{chat_history}
现在请回答这个问题：{question}

注意：严格按照检索到的内容进行回答，不要编造及额外拓展无关内容。
"""

# 构建提示词模板
prompt_with_history = PromptTemplate(
    input_variables = ["chat_history", "question"],
    template = prompt_with_history_str
)


chain_with_history = (
    {
        # itemgetter: 从输入字典中提取特定键，这里指定的是 messages 列表
        # 自定义 lambda 函数可用于进一步处理提取的数据，从 messages 列表中提取 question 和 chat_history
        "question": itemgetter("messages") | RunnableLambda(extract_question),
        "chat_history": itemgetter("messages") | RunnableLambda(extract_history)
    }
    | prompt_with_history
    | chat_model
    | StrOutputParser()
)

response = chain_with_history.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "论文作者叫什么名字？"
            }
        ]
    }
)

# ChatPromptTemplate
# Out:
# Content: 4.2 实验  ................................ ................................ ................................ . 42
# 4.2.1 实验设置  ................................ ................................ ...................  42
# 4.2.2 对比结果  ................................ ................................ ...................  42
# 4.2.3 消融实验  ................................ ................................ ...................  44
# 4.2.4 可视化分析  ................................ ................................ ...............  45
# 4.2.5 时间复杂度分析  ................................ ................................ ....... 46
# 4.2.6 参数敏感性分析  ................................ ................................ ....... 46
# 4.2.7 收敛性分析  ................................ ................................ ...............  47
# 4.3 本章小结  ................................ ................................ .........................  48
# 第五章  基于对比学习的带权多视图聚类  ................................ ............  49
# 5.1 算法设计  ................................ ................................ .........................  49
# 5.1.1 隐式图特征学习  ................................ ................................ ....... 49
# 5.1.2 语义空间的一致性学习  ................................ ...........................  51
# 5.1.3 基于标签的对比学习策略  ................................ .......................  52
# 5.1.4 模型训练和优化  ................................ ................................ ....... 53
# 5.2 实验  ................................ ................................ ................................ . 54
# 5.2.1 实验设置  ................................ ................................ ...................  54
# 5.2.2 对比结果  ................................ ................................ ...................  55
# 5.2.3 消融实验  ................................ ................................ ...................  56
# 5.2.4 可视化分析  ................................ ................................ ...............  57
# 5.2.5 参数敏感性分析  ................................ ................................ ....... 58
# 5.2.6 收敛性分析  ................................ ................................ ...............  59
# 5.3 本章小结  ................................ ................................ .........................  60
# 第六章  全文总结与展望  ................................ ................................ ........  61
# 6.1 全文总结  ................................ ................................ .........................  61
# 6.2 后续工作展望  ................................ ................................ .................  62
# 参考文献  ................................ ................................ ................................ ... 63 第一章 绪论
# 第一章 绪论
# 1.1研究工作的背景与意义
# 在人工智能（ Artificial Intelligence, AI ）快速发展的浪潮下，信息技术延伸到
# 全球的每一个角落，极大地改变了人类的社会生活，促进了经济结构的变革以及
# 社会生产力的提升。经过数十年的发展与演进，聚类算法已在众多学科领域和实
# 际场景中展现了其重要价值并得到广泛应用[1,2]。在模式识别领域，聚类技术通过
# 揭示数据内在的分布模式与结构特征，为研究者提供了深入理解数据集特性的有
# 效工具。在商业分析领域，聚类方法被广泛应用于市场细分，通过对客户群体的
# 精准划分，为企业制定差异化营销策略提供了数据驱动的决策支持。在计算机视
# 觉领域，聚类算法在图像分割任务中发挥着关键作用，通过对像素点的分组处理，
# 实现了图像中不同区域或目标对象的有效提取。在生物信息学领域，聚类技术为
# 高通量生物数据的分析提供了重要手段，助力科研人员从复杂的基因或蛋白质数
# 据中发现潜在规律。此外，在地理信息科学领域，聚类方法通过对空间数据的分
# 析，能够识别地理区域内的地物类型分布特征，为城市规划、环境监测等领域的
# 科学决策提供了可靠的数据支撑。
# 在数据驱动的人工智能时代，跨模态信息整合技术已成为提升模型认知能力
# 的关键突破口。传统基于单源信息的建模方法往往难以完整呈现对象的多维属性
# 特征，这种局限性促使研究者将注意力转向多源异构数据的协同分析。跨视角聚
# 类技术通过整合不同数据源间的潜在关联与互补信息，能够有效突破单一视角的
# 认知瓶颈，在工业检测、医疗影像分析、社交网络建模等实际场景中展现出显著
# 的应用优势。
# 作为非监督学习的重要分支，多模态聚类分析通过挖掘数据的内在分布规律，
# 将具有相似特征的数据样本划分为若干同质子集。该技术融合了机器学习、模式
# 识别、知识发现等交叉学科的理论方法，其核心价值体现在跨域特征融合与知识
# 迁移能力。在工程实践领域，这项技术已成功应用于高光谱图像解析、多传感器
# 数据融合、生物信息学建模等复杂场景。特别在自动驾驶环境感知、金融风险监
# 测、智能诊疗系统等前沿领域，跨视角数据整合方法正逐步成为提升系统决策可
# 靠性的关键技术支撑。当前研究亟需突破的难点在于如何构建更鲁棒的深度表征
# 学习框架，以解决数据间的语义鸿沟与噪声干扰问题，这正是未来探索的核心方
# 向。因此，高性能的多视图聚类方法 (如文献[3–5]所示 )具有重要的社会价值和良
# 好的应用前景。例如，如图 1-1所示，机器可以通过结合图像，音频，文本等多个
# 1电子科技大学硕士学位论文
# 图1-1多视图数据的示例
# 视图，来更加准确地分析网页信息。
# 在当前数据科学领域，图结构数据的应用场景日益广泛，这促使研究者们开
# 发了一系列创新的无监督图聚类技术。这些方法的核心在于深入挖掘和利用图数
# 据中蕴含的拓扑关系信息。与多源信息分析相类似，基于图模型的数据表征同样
# 展现出多维度的特性。在复杂网络系统中，实体节点之间往往存在着多种类型的
# 连接关系，这使得研究人员能够从同一组基础数据出发，构建出具有不同拓扑特
# 征的网络结构。这种具有多重图表示的数据组织形式被学术界定义为多视图图数
# Content: work[C]. IJCAI, 2021, 3230-3236.
# [59] Zhao L, Chen Z, Yang Y , et al. Incomplete multi-view clustering via deep semantic mapping[J].
# Neurocomputing, 2018, 275: 1053-1062.
# [60] Wang Q, Lian H, Sun G, et al. Icmsc: Incomplete cross-modal subspace clustering[J]. TIP, 2020,
# 30: 305-317.
# [61] Yang M, Li Y , Hu P, et al. Robust multi-view clustering with incomplete information[J]. TPAMI,
# 2022, 45(1): 1055-1069.
# 67电子科技大学硕士学位论文
# [62] Wen J, Zhang Z, Zhang Z, et al. Generalized incomplete multi-view clustering
# with flexible locality structure diffusion[J]. IEEE Transactions on Cybenetics, 2020,
# doi:10.1109/TCYB.2020.2987164.
# [63] Li Z, Tang C, Zheng X, et al. High-order correlation preserved incomplete multi-view subspace
# clustering[J]. TIP, 2022, 31(): 2067-2080.
# [64] Wang S, Liu X, Liu L, et al. Highly-efficient incomplete large-scale multi-view clustering with
# consensus bipartite graph[C]. CVPR, 2022, 9776-9785.
# [65] Liu C, Wu Z, Wen J, et al. Localized sparse incomplete multi-view clustering[J]. IEEE Transac-
# tions on Multimedia, 2022, 25: 5539-5551.
# [66] Liu C, Li R, Wu S, et al. Self-guided partial graph propagation for incomplete multiview cluster-
# ing[J]. IEEE transactions on neural networks and learning systems, 2024, 35(8): 10803-10816.
# [67] Wang S, Liu X, Liu S, et al. Align then fusion: Generalized large-scale multi-view clustering
# with anchor matching correspondences[J]. arXiv preprint arXiv:2205.15075, 2022.
# 68
# Content: 模型过度依赖图卷积模块，可能导致视图间的一致性学习不足，从而影响伪标签
# 的质量。实验数据显示，当时，模型的 NMI指标较最佳值下降了 18.9%。通过网
# 格搜索，发现当时，模型能够有效地平衡图卷积模块和对比学习模块的作用，从
# 而取得最优的聚类性能。因此，建议将的默认值设置为 0.5。
# 5.2.6收敛性分析
# 为了验证所提出算法的收敛特性，在 BDGP基准数据集上对模型的损失函数
# 进行了系统性分析。实验重点关注重构损失、聚类损失以及总损失随训练 epoch的
# 变化趋势。如图 5-5所示，随着迭代次数的增加，三类损失函数均呈现出明显的下
# 图5-5 BDGP 数据集上参数收敛性分析
# 59电子科技大学硕士学位论文
# 降趋势，并最终趋于平稳。具体而言，重构损失在前 30个epoch内快速下降，表
# 明模型能够有效捕捉数据的底层结构特征；聚类损失在 100个epoch后趋于稳定，
# 反映出算法在特征空间中的聚类分配逐渐达到最优状态；总损失函数在整个训练
# 过程中始终保持单调递减，最终收敛到一个稳定的极小值点。这种收敛行为不仅
# 验证了模型训练的稳定性，也从理论上支持了所提出方法的有效性。此外，损失
# 函数的平滑收敛曲线表明，所设计的优化策略能够避免陷入局部最优，确保了算
# 法解的可靠性。
# 5.3本章小结
# 本章提出了基于对比学习的带权多视图聚类方法，这一方法引入对比学习机
# 制，增强了模型对不同视图间共性与差异的捕捉能力，建立了一种视图一致性保
# 持与视图特性保留的平衡机制。具体来说，通过从原始数据中学习多粒度特征表
# 示，包括底层细节特征、高层抽象特征以及语义级特征表示，从而实现了不同特
# 征空间中的重建目标与一致性目标的协同优化。设计了一种端到端的深度聚类优
# 化框架，有效利用拓扑结构信息，将边缘性节点信息更聚拢于其聚类中心，使整
# 体类簇结构更为清晰化，该框架将表示学习与聚类任务深度融合，通过联合优化
# 特征表示与聚类目标，显著提升了聚类的准确性与鲁棒性。此外，通过大量实验
# 分析，验证了所提出框架的有效性。实验结果表明，该方法在多个真实世界数据
# 集上均取得了优异的性能，特别是在处理高维数据和复杂视图关系时，展现了显
# 著的优越性。
# 60第六章 全文总结与展望
# 第六章 全文总结与展望
# 6.1全文总结
# 在信息技术快速发展的背景下，数据规模呈现指数级增长，数据采集手段日
# 趋多元化，数据模态也日益丰富，这直接推动了多视图数据（ Multi-View Data ）研
# 究的兴起。由于多源异构数据的获取成本远低于高质量标注的成本，传统监督学
# 习方法面临着严峻挑战。在此背景下，多视图聚类技术作为一种高效的无监督学
# 习方法，近年来在机器学习与数据挖掘领域受到了广泛关注，并逐渐发展成为解
# 决高维异构数据分析问题的关键技术之一。
# 图结构数据现如今越来越普遍，其为聚类注入了新的活力，尽管如此，基于图
# 的多视图聚类的共同思想是通过原始图结构来学习视图之间面向任务的信息。然
# 而，在现实数据中，原始的图结构往往不存在，这限制了某些基于图的多视图聚类
# 模型的适用性，这些模型依赖于显式图数据或由原始特征构建的图作为输入。此
# 外，现有方法大多忽略了所有视图的潜在信息和拓扑信息的结合使用。因此，这
# 些方法的性能在很大程度上取决于输入图或原始特征。
# 基于以上发现，本文在第三章进行了相应探讨，提出了基于动态加权图融合
# 的深度多视图聚类框架。该方法通过深度自动编码器学习每个视图的嵌入式特征，
# 并构建隐式图以捕获视图内的拓扑信息。通过融合所有视图的嵌入特征和潜在图，
# 该框架能够有效整合不同视图的互补信息，从而提升聚类性能。更进一步，在第
# 四章通过跨视图对比学习机制实现多视图特征的有效融合。具体而言，该框架在
# 语义空间中实现了视图特定表示与统一表示的联合优化，通过语义对齐策略增强
# 了特征的一致性。此外，引入语义标签作为自监督信号，指导多视图特征空间中
# 的聚类分配过程，从而在保证视图间特征一致性的同时，充分保留了各视图的独
# 有信息。这种双重优化机制不仅从新的角度提升了表征的质量，更可作为一种通
# 用方案广泛的应用于现实场景中。现有方法普遍存在一个关键局限性：它们严重
# 依赖于视图数据的完整性假设。针对真实场景中的不完备多视图聚类问题，第五
# 章提出了一种基于潜在图的自适应特征插值方法。该方法通过所设计的自适应插
# 值模块动态恢复缺失样本，并结合图嵌入技术保持数据的局部结构。不仅利用潜
# 在图捕获拓扑信息，还通过融合图整合多视图的互补性，从而提高了不完整数据
# 上的聚类，相对于其他不完备多视图聚类方法表现更为优异。
# 综上所述，本文所提出的三种方法在实验中都表现出较高的性能，相对于现
# 有的同类方法来说，具有更好的聚类效果和稳定性。
# 61电子科技大学硕士学位论文
# 6.2后续工作展望
# 本研究在真实多视图数据集的处理上取得了一定进展，但考虑到实际应用场
# 景中数据的高度复杂性以及现有算法的局限性，仍存在若干需要改进和完善的方
# 面。基于当前研究的不足，未来工作将重点围绕以下几个方向展开深入探索：
# 首先，深度学习技术作为机器学习与人工智能领域的重要突破，在处理高
# 维、非线性数据方面展现出独特优势。其中，图神经网络（ Graph Neural Networks,
# GNNs）因其能够同时捕获数据的结构信息和属性特征而备受关注。通过将图卷积
# 操作与本文提出的一致性表示学习框架相结合，有望开发出更强大的深度潜在表
# 示学习方法。这种方法不仅能够更好地挖掘数据的内在规律，还能为复杂数据分
# 析提供新的技术支撑，具有重要的理论价值和广阔的应用前景。
# 其次，现实世界中的数据往往存在不完整性问题，这主要源于数据采集过程
# 中的设备故障、传输错误或存储限制等因素。这种数据缺失现象严重影响了多视
# 图聚类算法的性能，给实际应用带来了巨大挑战。因此，开发鲁棒的数据补全机
# 制和针对缺失视图的聚类算法成为亟待解决的关键科学问题。未来的研究将重点
# 关注以下两个方面：一是设计基于深度学习的自适应数据补全方法，以更准确地
# 恢复缺失信息；二是开发对数据缺失具有鲁棒性的新型聚类算法，从而提高算法
# 在实际应用中的可靠性。这些研究方向的突破将显著提升多视图学习技术的实用
# 价值，推动相关领域的进一步发展。
# 此外，随着数据规模的不断扩大和计算需求的日益增长，如何提高算法的计
# 算效率也是一个值得关注的研究方向。开发分布式计算框架或设计轻量级网络结
# 构可能成为解决这一问题的有效途径。同时，将多视图学习与其他先进技术（如
# 元学习、自监督学习等）相结合，也是未来值得探索的重要方向。这些研究将有
# 助于构建更加完善的多视图学习理论体系，并为实际应用提供更强大的技术支持。
# 62电子科技大学硕士学位论文
# 参考文献
# [1] Yang Z.-X, Tang L, Zhang K, et al. Multi-view cnn feature aggregation with elm auto-encoder
# for 3d shape recognition[J]. Cognitive Computation, 2018, 10(6): 908-921.
# [2] Fang U, Li M, Li J, et al. A comprehensive survey on multi-view clustering[J]. IEEE Transactions
# on Knowledge and Data Engineering, 2023, 35(12): 12350-12368.
# [3] Yang X, Deng C, Dang Z, et al. Deep multiview collaborative clustering[J]. IEEE Transactions
# on Neural Networks and Learning Systems, 2021, 34(1): 516-526.
# [4] Xu J, Tang H, Ren Y , et al. Multi-level feature learning for contrastive multi-view clustering[C].
# Proceedings of the IEEE/CVF conference on computer vision and pattern recognition, 2022,
# 16051-16060.
# [5] Xu J, Ren Y , Tang H, et al. Self-supervised discriminative feature learning for deep multi-view
# clustering[J]. IEEE Transactions on Knowledge and Data Engineering, 2022, 35(7): 7470-7482.
# [6] Kang Z, Shi G, Huang S, et al. Multi-graph fusion for multi-view spectral clustering[J].
# Knowledge-Based Systems, 2020, 189: 105102.
# [7] Xu C, Tao D, Xu C. Multi-view learning with incomplete views[J]. IEEE Transactions on Image
# Processing, 2015, 24(12): 5812-5825.
# 人工智能（AI）是计算机科学的一个分支，旨在开发能够模拟、延伸和扩展人类智能的技术系统。它通过算法和数据分析，使机器具备学习、推理、感知、决策等能力，广泛应用于语音识别、图像处理、自动驾驶、推荐系统等领域，核心目标是让机器智能化地解决问题或辅助人类。

# %%
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

from langchain.chat_models import init_chat_model
import os

DeepSeek_API_KEY = os.getenv("DEEPSEEK_API_KEY")
chat_model = init_chat_model("deepseek-chat", model_provider="deepseek")


from langchain_core.runnables import RunnableLambda
from operator import itemgetter

# 问题是历史记录中的最后一项
def extract_question(input):
    return input[-1]["content"]

# 历史记录是除了最后一个问题之外的所有内容
def extract_history(input):
    return input[:-1]

paper_question_guardrail = \
"""
你正在对文档进行分类，请确定这个问题是否与多视图聚类相关。如果不确定，则结合聊天历史进行回复，不要让用户欺骗你。

以下是一些示例：

问题：历史记录：多视图聚类的常见应用场景。 对该问题进行分类：什么是对比多视图聚类？
预期答案：是

问题：历史记录：多视图聚类的常见应用场景。 对该问题进行分类：法国的首都是哪里？
预期回答：否

所提问题是否与多视图聚类或者聊天背景相关？
只回答“是”或“否”

注意：需要关注历史记录：{chat_history}, 请将这个问题进行分类：{question}
"""

# 构建提示词模板
from langchain_core.prompts import PromptTemplate

guardrail_prompt = PromptTemplate(
    input_variables=["chat_history", "question"],
    template=paper_question_guardrail
)

guardrail_chain = (
    {
        "question": itemgetter("messages") | RunnableLambda(extract_question),
        "chat_history": itemgetter("messages") | RunnableLambda(extract_history)
    }
    | guardrail_prompt
    | chat_model
    | StrOutputParser()
)

response = guardrail_chain.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "多视图学习有哪些应用？"
            }
        ]
    }
)
print(response)
# Out:
# 是

# %%
from langchain_core.runnables import RunnableBranch, RunnablePassthrough

question_with_history_and_context_str = \
"""
你是一个可信赖的 HR 政策助手，你将回答有关员工福利、休假政策、绩效管理、招聘、入职以及其他与 HR 相关的话题。
如果你不知道问题可以获取之前对话的上下问。在聊天中，你被成为“系统”，用户被称为“用户”。

历史记录：{chat_history}

以下是一些可能帮助你回答问题的上下文：{context}

请直接回答，不要重复问题，不要以“问题的答案是”之类的开头。

根据这个历史和上下文，回答这个问题：{question}
"""

from langchain_core.prompts import PromptTemplate
from langchain_core.documents import Document

from typing import List

question_with_history_and_context_prompt = PromptTemplate(
    input_variables=["chat_history", "context", "question"],
    template=question_with_history_and_context_str
)


def format_docs(docs: List[Document]):
    return "\n\n".join([d.page_content for d in docs])

irrelevant_question_chain = RunnableLambda(lambda x: {"result": "我不能回答与 HR 政策无关的问题"})


relevant_question_chain = (
    RunnablePassthrough()
    |
    {
        "relevant_docs": prompt | chat_model | StrOutputParser() | retriever,
        "chat_history": itemgetter("chat_history"),
        "question": itemgetter("question")
    }
    |
    {
        "context": itemgetter("relevant_docs") | RunnableLambda(format_docs),
        "chat_history": itemgetter("chat_history"),
        "question": itemgetter("question")
    }
    |
    {
        "prompt": question_with_history_and_context_prompt
    }
    |
    {
        "result": itemgetter("prompt") | chat_model | StrOutputParser()
    }
)

branch_node = RunnableBranch(
    (lambda x: "是" in x["question_is_relevant"].lower(), relevant_question_chain),
    (lambda x: "否" in x["question_is_relevant"].lower(), irrelevant_question_chain),
    irrelevant_question_chain
)

full_chain = (
    {
        "question_is_relevant": guardrail_chain,
        "question": itemgetter("messages") | RunnableLambda(extract_question),
        "chat_history": itemgetter("messages") | RunnableLambda(extract_history)
    }
    | branch_node
)


import json

non_relevant_dialog = {
    "messages": [
        {"role": "user", "content": "公司的病假政策"},
        {"role": "assistant", "content": "xxx"},
        {"role": "user", "content": "你的名字是什么"}
    ]
}


response = full_chain.invoke(non_relevant_dialog)
